# %%
from PIL import Image
import os
from tetra.model import inference
from tetra.utils import file_io, viewer
import sahi
import matplotlib.pyplot as plt
from pathlib import Path
import importlib

# %%
model_path = os.path.abspath("../../runs/train/lyrurus_yolov8m_new_dataset/weights/best.pt")
image_path = os.path.abspath("../../dataset_og")  
save_dir = os.path.abspath("../../outputs/labels")
class_file = os.path.abspath("../classes.txt")

# %%
importlib.reload(file_io)
# Out:
# <module 'tetra.utils.file_io' from '/Users/mateobigearddasen/Documents/agrosup_stage/Tetra_Project/src/tetra/utils/file_io.py'>

# %%
for img in Path(image_path).iterdir():
    if img.suffix.lower() == ".jpg":
        res = inference.inference(model_path=model_path, image_path=str(img))
        # Convert to YOLO
        yolo_labels = file_io.coco_to_yolo(res.to_coco_annotations(), str(img))
        
        # Get image name (without extension)
        image_name = img.stem + ".txt"
        
        # Save labels
        file_io.save_yolo_labels(yolo_labels, save_dir, image_name)
# Out:
# Performing prediction on 20 slices.
# Performing prediction on 20 slices.
# Performing prediction on 20 slices.
# Performing prediction on 20 slices.
# Performing prediction on 20 slices.

# %%
for img in Path(image_path).iterdir():
    if img.suffix.lower() == ".jpg":
        print(img.stem + "text")
        image = viewer.view_image(img, os.path.join(save_dir,img.stem + ".txt"), class_file,0.385)
        plt.imshow(image)
        plt.title("Inference")
        plt.axis("off")
        plt.show()
# Out:
# 04160106_JPG.rf.7c259a54716693ca8ccb7bc2119454a7text
# ['0', '0.663763', '0.410374', '0.030705', '0.026973', '0.853791']
# ['0', '0.723413', '0.389568', '0.022478', '0.018508', '0.795409']
# ['0', '0.693154', '0.388175', '0.020924', '0.017419', '0.779881']
# ['0', '0.468826', '0.973096', '0.034457', '0.033969', '0.680820']
# ['0', '0.781803', '0.970726', '0.024156', '0.025769', '0.570007']
# ['0', '0.390740', '0.970219', '0.015137', '0.022071', '0.417813']
# 04160107_JPG.rf.044333ebd343ddc670b113b7631d0cebtext
# ['0', '0.658613', '0.410923', '0.027864', '0.025472', '0.836260']
# ['0', '0.695477', '0.387528', '0.018136', '0.019707', '0.820267']
# ['0', '0.836921', '0.368039', '0.017222', '0.024034', '0.809658']
# ['0', '0.725716', '0.390537', '0.024328', '0.021922', '0.710895']
# ['0', '0.469155', '0.973116', '0.033849', '0.033853', '0.671907']
# ['0', '0.781604', '0.970789', '0.024017', '0.025889', '0.629556']
# ['0', '0.324212', '0.197971', '0.118043', '0.099243', '0.379982']
# ['0', '0.390657', '0.970237', '0.015153', '0.022061', '0.371446']
# 04160108_JPG.rf.20c91f5f3101b4343fdd87fad90bf2fdtext
# ['0', '0.655057', '0.411266', '0.027709', '0.026010', '0.808736']
# ['0', '0.835859', '0.366612', '0.015849', '0.022603', '0.793428']
# ['0', '0.731586', '0.390518', '0.024266', '0.024905', '0.783488']
# ['0', '0.703651', '0.387096', '0.024398', '0.023610', '0.694604']
# ['0', '0.469258', '0.973024', '0.033518', '0.033641', '0.676803']
# ['0', '0.818784', '0.043187', '0.041177', '0.048046', '0.658714']
# ['0', '0.397011', '0.970919', '0.025672', '0.025226', '0.656774']
# ['0', '0.781635', '0.970780', '0.023825', '0.025631', '0.611735']
# 04160109_JPG.rf.d34b18f3398d8d637ea71a4b913e09ebtext
# ['0', '0.776333', '0.372549', '0.021669', '0.020097', '0.839115']
# ['0', '0.494742', '0.420914', '0.023577', '0.029893', '0.793764']
# ['0', '0.802725', '0.395628', '0.019051', '0.019641', '0.763535']
# ['0', '0.468750', '0.973073', '0.034692', '0.033608', '0.662035']
# ['0', '0.781570', '0.970764', '0.023894', '0.025981', '0.632450']
# ['0', '0.397009', '0.970979', '0.025436', '0.024845', '0.621993']
# 04160110_JPG.rf.54148cf7aa340b30973069c8001b8254text
# ['0', '0.770782', '0.372734', '0.009714', '0.021559', '0.836635']
# ['0', '0.803080', '0.395204', '0.017961', '0.018595', '0.813303']
# ['0', '0.491849', '0.423323', '0.016627', '0.021822', '0.781292']
# ['0', '0.468838', '0.973051', '0.034427', '0.033550', '0.670827']
# ['0', '0.781548', '0.970765', '0.023803', '0.025939', '0.660462']
# ['0', '0.397072', '0.970983', '0.025488', '0.024896', '0.631531']
# ['0', '0.982398', '0.971575', '0.026083', '0.024756', '0.411363']
